# %% [markdown]
# # Approach 5: Splink + DuckDB Entity Resolution
#
# Run the dry-run cell first, inspect candidate counts and validation F0.5, then launch the full pipeline.

# %%
# %pip install -q -r /kaggle/working/student_resource/approach_5_splink/requirements.txt
# !python /kaggle/working/student_resource/approach_5_splink/run_pipeline.py --dry-run --subset-size 1000

# %%
# !python /kaggle/working/student_resource/approach_5_splink/run_pipeline.py

# %%
import os
from pathlib import Path
output_dir = Path('/kaggle/working/output')
print(list(output_dir.glob('*.tsv')))
test_dir = next(Path('/kaggle/input').rglob('test_source1.tsv')).parent
print(f'Validator test directory: {test_dir}')
# !python /kaggle/working/student_resource/utils/validate_submission.py --matching /kaggle/working/output/matching_results.tsv --candidate /kaggle/working/output/candidate_pairs.tsv --test-dir {test_dir}
