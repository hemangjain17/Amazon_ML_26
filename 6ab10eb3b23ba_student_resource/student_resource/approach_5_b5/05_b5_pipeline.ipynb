# %% [markdown]
# # Approach 5: B5-seg + two-stage LightGBM
#
# Run the smoke job first, then the full country-partitioned inference pipeline.

# %%
# %pip install -q -r /kaggle/working/Amazon_ML_26/6ab10eb3b23ba_student_resource/student_resource/approach_5_b5/requirements.txt
# !python /kaggle/working/Amazon_ML_26/6ab10eb3b23ba_student_resource/student_resource/approach_5_b5/run_pipeline.py --dry-run --s1-limit 10000 --pool-limit 100000 --output-dir /kaggle/working/output_smoke

# %%
# !python /kaggle/working/Amazon_ML_26/6ab10eb3b23ba_student_resource/student_resource/approach_5_b5/run_pipeline.py --output-dir /kaggle/working/output --s1-chunk-size 10000 --max-train-pairs 2000000 --threads 4

# %%
from pathlib import Path
import subprocess
test_dir = next(Path('/kaggle/input').rglob('test_source1.tsv')).parent
subprocess.run(['python', '/kaggle/working/Amazon_ML_26/6ab10eb3b23ba_student_resource/student_resource/utils/validate_submission.py', '--matching', '/kaggle/working/output/matching_results.tsv', '--candidate', '/kaggle/working/output/candidate_pairs.tsv', '--test-dir', str(test_dir)], check=False)
